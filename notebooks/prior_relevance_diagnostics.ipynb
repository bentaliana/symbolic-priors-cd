# %% [markdown]
# # Prior-relevance diagnostic visuals

# %% [markdown]
# ## 1. Setup and run identity

# %%
from pathlib import Path
import sys
import json
import pandas as pd
from IPython.display import Image, Markdown, display

OUTPUT_ROOT = Path.cwd().parent if (Path.cwd().name == "notebooks") else Path.cwd()
if str(OUTPUT_ROOT) not in sys.path:
    sys.path.insert(0, str(OUTPUT_ROOT))

MAIN_EVAL_HASH = "864fe6722256"
PRIOR_RELEVANCE_HASH = "1b46785b59a4"
ORACLE_HASH = "1b95c563db88"

DIAGNOSTICS_DIR = (
    OUTPUT_ROOT / "results" / "main_study" / "exploratory"
    / "prior_relevance_diagnostics"
)
FIG_DIR = DIAGNOSTICS_DIR / "figures"
MANIFEST_PATH = DIAGNOSTICS_DIR / "prior_relevance_diagnostics_manifest.json"
CLAIM_TABLE_PATH = DIAGNOSTICS_DIR / "table_claim_support_matrix.csv"
print("main_evaluation_run_hash12:", MAIN_EVAL_HASH)
print("prior_relevance_analysis_hash12:", PRIOR_RELEVANCE_HASH)
print("oracle_analysis_hash12:", ORACLE_HASH)
print("figures dir:", FIG_DIR)
# Out:
# main_evaluation_run_hash12: 864fe6722256
# prior_relevance_analysis_hash12: 1b46785b59a4
# oracle_analysis_hash12: 1b95c563db88
# figures dir: c:\Users\benja\OneDrive\Desktop\Bsc. A.I\Thesis\symbolic-priors-cd\results\main_study\exploratory\prior_relevance_diagnostics\figures

# %% [markdown]
# ## 2. Data availability audit

# %%
if MANIFEST_PATH.exists():
    manifest = json.loads(MANIFEST_PATH.read_text(encoding="utf-8"))
    display(Markdown("Manifest top-level keys:"))
    display(Markdown(", ".join(sorted(manifest.keys()))))
    display(Markdown("Inputs read:"))
    for name in manifest.get("inputs_used", []):
        print(" -", name)
else:
    display(Markdown("manifest not found; run the renderer first."))
# Out:
# Manifest top-level keys:
# audit, claim_support_matrix_path, generated_figures, inputs_used, main_evaluation_run_hash12, no_metric_recomputation, no_new_fits, no_new_sampling, no_protocol_changes, notebook_path, oracle_analysis_hash12, prior_relevance_analysis_hash12, skipped_figures, summary_markdown_path
# Inputs read:
#  - aggregated_error_heatmap_png
#  - baseline_comparison_csv
#  - degradation_summary_csv
#  - forbidden_engagement_summary_csv
#  - offline_removal_effect_csv
#  - oracle_manifest_json
#  - oracle_per_seed_csv
#  - oracle_summary_csv
#  - prior_free_error_decomposition_csv
#  - prior_relevance_manifest_json
#  - prior_target_overlap_csv
#  - reference_forbidden_comparison_csv

# %% [markdown]
# ## 3. Main result: mechanism without clear clean-prior metric improvement

# %%
path = FIG_DIR / "fig01_main_result_clean_metrics.png"
display(Markdown("Clean-grid mean SID / MMD / SHD per method family."))
if path.exists(): display(Image(filename=str(path)))
else: display(Markdown("(figure not generated; see manifest)"))
# Out:
# Clean-grid mean SID / MMD / SHD per method family.

# %%
path = FIG_DIR / "fig02_mechanism_engagement.png"
display(Markdown("Clean prior-engagement diagnostic: targeted |W| and fraction-above-threshold per method."))
if path.exists(): display(Image(filename=str(path)))
else: display(Markdown("(figure not generated; see manifest)"))
# Out:
# Clean prior-engagement diagnostic: targeted |W| and fraction-above-threshold per method.

# %%
path = FIG_DIR / "fig03_corruption_degradation.png"
display(Markdown("Corruption-axis degradation slope per method family and confidence."))
if path.exists(): display(Image(filename=str(path)))
else: display(Markdown("(figure not generated; see manifest)"))
# Out:
# Corruption-axis degradation slope per method family and confidence.

# %% [markdown]
# ## 4. Prior structural relevance motivation: were the prior targets relevant?

# %%
path = FIG_DIR / "fig04_error_decomposition.png"
display(Markdown("Prior-free per-seed error decomposition with targeted-FP count."))
if path.exists(): display(Image(filename=str(path)))
else: display(Markdown("(figure not generated; see manifest)"))
# Out:
# Prior-free per-seed error decomposition with targeted-FP count.

# %% [markdown]
# ## 5. Prior structural relevance: target overlap and offline removal

# %%
path = FIG_DIR / "fig05_prior_target_overlap.png"
display(Markdown("Fraction of reference forbidden edges predicted, per method family."))
if path.exists(): display(Image(filename=str(path)))
else: display(Markdown("(figure not generated; see manifest)"))
# Out:
# Fraction of reference forbidden edges predicted, per method family.

# %%
path = FIG_DIR / "fig06_offline_removal_effect.png"
display(Markdown("Per-seed dSID and dSHD when reference forbidden edges are zeroed offline."))
if path.exists(): display(Image(filename=str(path)))
else: display(Markdown("(figure not generated; see manifest)"))
# Out:
# Per-seed dSID and dSHD when reference forbidden edges are zeroed offline.

# %%
path = FIG_DIR / "fig07_aggregated_error_heatmap.png"
display(Markdown("Aggregated structural-error heatmap (copied from upstream analysis)."))
if path.exists(): display(Image(filename=str(path)))
else: display(Markdown("(figure not generated; see manifest)"))
# Out:
# Aggregated structural-error heatmap (copied from upstream analysis).

# %% [markdown]
# ## 6. Oracle motivation: what if targets were better aligned?

# %% [markdown]
# Oracle scenarios use ground-truth information to select edges.

# %% [markdown]
# ## 7. Oracle evidence: exact FP diagnostic and greedy FN diagnostic

# %%
path = FIG_DIR / "fig08_oracle_summary.png"
display(Markdown("Mean dSID and dSHD per oracle scenario."))
if path.exists(): display(Image(filename=str(path)))
else: display(Markdown("(figure not generated; see manifest)"))
# Out:
# Mean dSID and dSHD per oracle scenario.

# %%
path = FIG_DIR / "fig09_oracle_per_seed_sid_delta.png"
display(Markdown("Per-seed dSID strip plot by oracle scenario; diamond = mean."))
if path.exists(): display(Image(filename=str(path)))
else: display(Markdown("(figure not generated; see manifest)"))
# Out:
# Per-seed dSID strip plot by oracle scenario; diamond = mean.

# %%
path = FIG_DIR / "fig10_required_edge_acyclicity.png"
display(Markdown("Per-seed selected vs skipped FN edge counts under the acyclicity constraint."))
if path.exists(): display(Image(filename=str(path)))
else: display(Markdown("(figure not generated; see manifest)"))
# Out:
# Per-seed selected vs skipped FN edge counts under the acyclicity constraint.

# %% [markdown]
# ## 8. Reconciling false-negative counts with false-positive leverage

# %%
path = FIG_DIR / "fig11_fp_vs_fn_reconciliation.png"
display(Markdown("Prior-free FN edges outnumber FPs, but FP removal carries the SID leverage."))
if path.exists(): display(Image(filename=str(path)))
else: display(Markdown("(figure not generated; see manifest)"))
# Out:
# Prior-free FN edges outnumber FPs, but FP removal carries the SID leverage.

# %% [markdown]
# ## 9. Claim-support matrix
#
# Rows describe each labelling-only claim, the figure or table that supports it, the source file, and the caveat that bounds the evidence.

# %%
if CLAIM_TABLE_PATH.exists():
    claim_df = pd.read_csv(CLAIM_TABLE_PATH)
    display(claim_df)
else:
    display(Markdown("(claim-support matrix not generated; see manifest)"))
# Out:
#                                        claim_label  \
# 0                  soft_prior_engaged_mechanically
# 1    clean_metric_improvement_not_clearly_observed
# 2             original_targets_covered_limited_fps
# 3       original_target_removal_small_or_mixed_sid
# 4  exact_fp_budget_targeting_high_sid_shd_leverage
# 5      required_edge_repair_acyclicity_constrained
# 6                   no_mmd_counterfactual_computed
#
#                                      supported_claim  \
# 0  Soft prior reduces targeted |W| and threshold-...
# 1  Soft prior at clean / confidence 1.0 did not s...
# 2  Original 10-edge forbidden set covered only a ...
# 3  Offline removal of the original forbidden edge...
# 4  Exact 10-edge FP-targeted removal yielded much...
# 5  Greedy FN repair skipped many candidate edges ...
# 6  Oracle diagnostics do not recompute MMD; no co...
#
#             supporting_figure_or_table  \
# 0       fig02_mechanism_engagement.png
# 1  fig01_main_result_clean_metrics.png
# ...

# %% [markdown]
# ## 10. Output manifest

# %%
if MANIFEST_PATH.exists():
    print("Generated figures:")
    for name in sorted(manifest.get("generated_figures", {})):
        print(" -", name)
    skipped = manifest.get("skipped_figures", {})
    if skipped:
        print("Skipped figures:")
        for name, reason in sorted(skipped.items()):
            print(" -", name, "(" + str(reason) + ")")
    print("All artefacts loaded. Thesis interpretation is separate.")
# Out:
# Generated figures:
#  - fig01_main_result_clean_metrics.png
#  - fig02_mechanism_engagement.png
#  - fig03_corruption_degradation.png
#  - fig04_error_decomposition.png
#  - fig05_prior_target_overlap.png
#  - fig06_offline_removal_effect.png
#  - fig07_aggregated_error_heatmap.png
#  - fig08_oracle_summary.png
#  - fig09_oracle_per_seed_sid_delta.png
#  - fig10_required_edge_acyclicity.png
#  - fig11_fp_vs_fn_reconciliation.png
# All artefacts loaded. Thesis interpretation is separate.
